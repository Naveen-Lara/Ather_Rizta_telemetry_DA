# %% [markdown]
# # Data Understanding and Loading

# %%
## importing all the libraries
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
## Loading the dataset 
df = pd.read_csv("ride_data.csv") 
df.index=range(1,len(df)+1)

# %%
df.head()
# Out:
#              Timestamp  Ride_Mode  Front_PSI   Rear_PSI  Motor_Current  \
# 1  2025-01-01 08:00:00  Smart Eco  22.072488  36.041235       4.000000
# 2  2025-01-01 08:00:05  Smart Eco  22.103992        NaN      11.881297
# 3  2025-01-01 08:00:10  Smart Eco  22.061601  35.998044      12.090489
# 4  2025-01-01 08:00:15  Smart Eco  22.138960  35.911912      11.821425
# 5  2025-01-01 08:00:20  Smart Eco  22.082344  35.825733      12.051667
#
#    Motor_Temp  Battery_Voltage  Discharge_Current  Battery_Temp  \
# 1   28.060000        58.585477           4.200000     28.042000
# 2   28.236419        58.413992          12.475362     28.165914
# 3   28.410684        58.428662          12.695014     28.289545
# 4   28.575685        58.357180          12.412497     28.407880
# 5   28.739190        58.476819          12.654250     28.526264
#
#    Voltage_Difference  Battery_Impedance      Speed  Regen_Triggered  \
# 1           11.175623          84.628469   4.783331            False
# 2           12.444158          84.787273  45.133331            False
# 3           13.329309          84.988065  47.133308            False
# 4            9.244121          85.226445  42.681162            False
# 5           12.051001          84.265367  38.736622            False
#
#    Regen_Current        SOC  Energy_Consumed_Wh       Ride_ID  Distance_km
# 1            0.0  94.988220            0.341749  2025-01-01_8     0.006644
# 2            0.0  94.953326            1.012133  2025-01-01_8     0.062685
# 3            0.0  94.917802            1.030212  2025-01-01_8     0.065463
# 4            0.0  94.883103            1.006053  2025-01-01_8     0.059279
# 5            0.0  94.847689            1.027750  2025-01-01_8     0.053801

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 1 to 18000
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Timestamp           18000 non-null  object
#  1   Ride_Mode           18000 non-null  object
#  2   Front_PSI           17822 non-null  float64
#  3   Rear_PSI            17830 non-null  float64
#  4   Motor_Current       18000 non-null  float64
#  5   Motor_Temp          18000 non-null  float64
#  6   Battery_Voltage     18000 non-null  float64
#  7   Discharge_Current   18000 non-null  float64
#  8   Battery_Temp        18000 non-null  float64
#  9   Voltage_Difference  17819 non-null  float64
#  10  Battery_Impedance   18000 non-null  float64
#  11  Speed               18000 non-null  float64
#  12  Regen_Triggered     18000 non-null  bool
#  13  Regen_Current       18000 non-null  float64
#  14  SOC                 18000 non-null  float64
#  15  Energy_Consumed_Wh  18000 non-null  float64
#  16  Ride_ID             18000 non-null  object
#  17  Distance_km         18000 non-null  float64
# dtypes: bool(1), float64(14), object(3)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#           Front_PSI      Rear_PSI  Motor_Current    Motor_Temp  \
# count  17822.000000  17830.000000   18000.000000  18000.000000
# mean      21.039369     34.270955      30.334528     41.879422
# std        0.639640      1.041747      10.469170      5.425367
# min       19.785705     32.290501       4.000000     28.060000
# 25%       20.488126     33.369316      21.587489     37.558077
# 50%       21.042384     34.265829      30.572064     42.189955
# 75%       21.591928     35.165731      39.397192     46.592611
# max       22.237094     36.252165      45.000000     50.474559
#
#        Battery_Voltage  Discharge_Current  Battery_Temp  Voltage_Difference  \
# count     18000.000000       18000.000000  18000.000000        17819.000000
# mean         57.750592          31.851255     39.455966           12.010948
# std           0.364207          10.992629      3.485287            2.007328
# min          56.913806           4.200000     28.042000            5.000000
# 25%          57.444426          22.666864     37.322460           10.670662
# 50%          57.729348          32.100667     41.781280           12.020560
# 75%          58.037739          41.367052     42.000000           13.379927
# max          58.800000          47.250000     42.000000           20.000000
#
#        Battery_Impedance         Speed  Regen_Current           SOC  \
# count       18000.000000  18000.000000   18000.000000  18000.000000
# mean           85.504369     49.940201      -4.275413     78.802586
# std             0.507170     11.271611       6.692359     10.820476
# min            83.855742      3.008377     -15.000000     50.178373
# 25%            85.150408     42.483865     -14.271645     70.875415
# 50%            85.503240     47.544982       0.000000     80.380038
# 75%            85.853473     55.000000       0.000000     87.921640
# max            87.496981     80.000000       0.000000     94.988224
#
#        Energy_Consumed_Wh   Distance_km
# count        18000.000000  18000.000000
# mean             2.549432      0.069361
# std              0.867045      0.015655
# min              0.341306      0.004178
# 25%              1.826084      0.059005
# 50%              2.574679      0.066035
# 75%              3.299894      0.076389
# max              3.780685      0.111111

# %%
df["Ride_Mode"].value_counts() # Unique categorical_values
# Out:
# Ride_Mode
# Smart Eco    13295
# Zip           4705
# Name: count, dtype: int64

# %%
df[["Ride_Mode","Regen_Triggered"]].value_counts()
# Out:
# Ride_Mode  Regen_Triggered
# Smart Eco  False              9718
#            True               3577
# Zip        False              3052
#            True               1653
# Name: count, dtype: int64

# %% [markdown]
# # 2. Data Preparation (Cleaning & Transformation)

# %% [markdown]
# ## Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Timestamp               0
# Ride_Mode               0
# Front_PSI             178
# Rear_PSI              170
# Motor_Current           0
# Motor_Temp              0
# Battery_Voltage         0
# Discharge_Current       0
# Battery_Temp            0
# Voltage_Difference    181
# Battery_Impedance       0
# Speed                   0
# Regen_Triggered         0
# Regen_Current           0
# SOC                     0
# Energy_Consumed_Wh      0
# Ride_ID                 0
# Distance_km             0
# dtype: int64

# %%
sns.histplot(df["Front_PSI"],kde=True)
# Out:
# <Axes: xlabel='Front_PSI', ylabel='Count'>

# %%
## not skewed so handling the nulls with mean()
df["Front_PSI"]=df["Front_PSI"].fillna(df["Front_PSI"].mean().round())

# %%
df["Front_PSI"].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.histplot(df["Front_PSI"],kde=True)
# Out:
# <Axes: xlabel='Front_PSI', ylabel='Count'>

# %%
null_cols=df.columns[df.isnull().any()]

# %%
null_cols= df[null_cols]

# %%
null_cols.head() ## handling them separately and later replaced in the main table
# Out:
#     Rear_PSI  Voltage_Difference
# 1  36.041235           11.175623
# 2        NaN           12.444158
# 3  35.998044           13.329309
# 4  35.911912            9.244121
# 5  35.825733           12.051001

# %%
## Visualising the columns 
for col in null_cols:
    sns.histplot(null_cols[col],kde=True)
    plt.title(null_cols[col].skew().round(3))
    plt.show()

# %%
null_cols.columns
# Out:
# Index(['Rear_PSI', 'Voltage_Difference'], dtype='object')

# %%
for col in null_cols:
    if abs(null_cols[col].skew()) <= 0.5:
        null_cols[col]= null_cols[col].fillna(null_cols[col].mean().round(1))
    elif abs(null_cols[col].skew()) >= 0.5  and abs(null_cols[col]) <= 1:
        null_cols[col]= null_cols[col].fillna(null_cols[col].median().round(1))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21284\1998633949.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_cols[col]= null_cols[col].fillna(null_cols[col].mean().round(1))

# %%
for col in null_cols:
    sns.histplot(null_cols[col],kde=True)
    plt.title(null_cols[col].skew().round(3))
    plt.show()

# %%
df[null_cols.columns]= null_cols

# %%
df.isnull().sum() # handled all the missing values
# Out:
# Timestamp             0
# Ride_Mode             0
# Front_PSI             0
# Rear_PSI              0
# Motor_Current         0
# Motor_Temp            0
# Battery_Voltage       0
# Discharge_Current     0
# Battery_Temp          0
# Voltage_Difference    0
# Battery_Impedance     0
# Speed                 0
# Regen_Triggered       0
# Regen_Current         0
# SOC                   0
# Energy_Consumed_Wh    0
# Ride_ID               0
# Distance_km           0
# dtype: int64

# %%
for col in df.select_dtypes(include="number").columns:
    sns.histplot(df[col],kde=True)
    plt.title(df[col].skew().round(3))
    plt.tight_layout()
    plt.show()

# %%
def df_skew(table):
    skews={}
    highly_skewed={}
    for col in table.select_dtypes(include="number").columns:
        skew_value=float(table[col].skew().round(2))
        skews[col]=skew_value
        if abs(skew_value)>1:
            highly_skewed[col] = skew_value
        
        
    return skews, highly_skewed

# %%
df_skew(df)
# Out:
# ({'Front_PSI': 0.0,
#   'Rear_PSI': 0.0,
#   'Motor_Current': -0.11,
#   'Motor_Temp': -0.26,
#   'Battery_Voltage': 0.19,
#   'Discharge_Current': -0.11,
#   'Battery_Temp': -1.29,
#   'Voltage_Difference': -0.03,
#   'Battery_Impedance': 0.02,
#   'Speed': 0.71,
#   'Regen_Current': -0.93,
#   'SOC': -0.45,
#   'Energy_Consumed_Wh': -0.12,
#   'Distance_km': 0.71},
#  {'Battery_Temp': -1.29})

# %%
outlier_columns=df[["SOC","Motor_Temp"]]

# %%
for col in outlier_columns:
    sns.histplot(outlier_columns[col],bins=30,kde=True)
    plt.show()

# %%
from scipy import stats
outlier_columns["SOC_boxcox"],_= stats.boxcox(outlier_columns["SOC"]+ 1e-6 )
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21284\170366926.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outlier_columns["SOC_boxcox"],_= stats.boxcox(outlier_columns["SOC"]+ 1e-6 )

# %%
sns.histplot(data=outlier_columns[["SOC","SOC_boxcox"]],kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
outlier_columns[["SOC"]].value_counts()
# Out:
# SOC
# 94.988199    1
# 94.988192    1
# 94.988191    1
# 94.988190    1
# 94.988190    1
#             ..
# 50.615821    1
# 50.505987    1
# 50.398829    1
# 50.292114    1
# 50.178373    1
# Name: count, Length: 18000, dtype: int64

# %% [markdown]
# # Dependent Columns
# ### The State of Charge (SOC) is closely linked with several other columns due to the physical and operational relationships in an electric scooter:
#
# ###  Battery_Voltage: SOC and voltage are directly related—as SOC drops, so does battery voltage, and vice versa.
#
# ###  Discharge_Current: Higher current draws deplete SOC faster.
#
# ###  Motor_Current: Motor current is a direct driver of discharge current (and thus SOC depletion).
#
# ###  Battery_Temp: Extreme temperatures can affect SOC measurement accuracy and battery efficiency.
#
# ###  Battery_Impedance: Higher impedance can cause voltage sag, affecting SOC estimation.
#
# ###  Speed, Acceleration, Incline_Angle: These influence current draw and thus SOC depletion rate.
#
# ###  Regen_Current: Regenerative braking can temporarily increase SOC (but this is usually a small effect in practice).

# %%
soc_dep=df[["SOC","Battery_Voltage","Discharge_Current","Motor_Current","Battery_Temp","Battery_Impedance","Regen_Current"]]

# %%
soc_dep
# Out:
#              SOC  Battery_Voltage  Discharge_Current  Motor_Current  \
# 1      94.988220        58.585477           4.200000       4.000000
# 2      94.953326        58.413992          12.475362      11.881297
# 3      94.917802        58.428662          12.695014      12.090489
# 4      94.883103        58.357180          12.412497      11.821425
# 5      94.847689        58.476819          12.654250      12.051667
# ...          ...              ...                ...            ...
# 17996  50.615821        57.350538          44.654277      42.527883
# 17997  50.505987        57.483695          39.851869      37.954161
# 17998  50.398829        57.517481          38.840060      36.990533
# 17999  50.292114        57.521673          38.680952      36.839002
# 18000  50.178373        57.426644          41.300638      39.333941
#
#        Battery_Temp  Battery_Impedance  Regen_Current
# 1         28.042000          84.628469       0.000000
# 2         28.165914          84.787273       0.000000
# 3         28.289545          84.988065       0.000000
# 4         28.407880          85.226445       0.000000
# 5         28.526264          84.265367       0.000000
# ...             ...                ...            ...
# 17996     42.000000          86.650225       0.000000
# 17997     42.000000          86.089176     -11.527581
# 17998     42.000000          86.559515       0.000000
# 17999     42.000000          86.438554       0.000000
# 18000     42.000000          86.329432       0.000000
#
# [18000 rows x 7 columns]

# %%
df
# Out:
#                  Timestamp  Ride_Mode  Front_PSI   Rear_PSI  Motor_Current  \
# 1      2025-01-01 08:00:00  Smart Eco  22.072488  36.041235       4.000000
# 2      2025-01-01 08:00:05  Smart Eco  22.103992  34.300000      11.881297
# 3      2025-01-01 08:00:10  Smart Eco  22.061601  35.998044      12.090489
# 4      2025-01-01 08:00:15  Smart Eco  22.138960  35.911912      11.821425
# 5      2025-01-01 08:00:20  Smart Eco  22.082344  35.825733      12.051667
# ...                    ...        ...        ...        ...            ...
# 17996  2025-01-25 18:29:35  Smart Eco  19.940938  32.526712      42.527883
# 17997  2025-01-25 18:29:40  Smart Eco  20.047073  32.555176      37.954161
# 17998  2025-01-25 18:29:45  Smart Eco  19.947056  32.632559      36.990533
# 17999  2025-01-25 18:29:50  Smart Eco  19.982741  32.526898      36.839002
# 18000  2025-01-25 18:29:55  Smart Eco  19.972233  32.387305      39.333941
#
#        Motor_Temp  Battery_Voltage  Discharge_Current  Battery_Temp  \
# 1       28.060000        58.585477           4.200000     28.042000
# 2       28.236419        58.413992          12.475362     28.165914
# 3       28.410684        58.428662          12.695014     28.289545
# 4       28.575685        58.357180          12.412497     28.407880
# 5       28.739190        58.476819          12.654250     28.526264
# ...           ...              ...                ...           ...
# 17996   49.111148        57.350538          44.654277     42.000000
# 17997   49.047126        57.483695          39.851869     42.000000
# 17998   48.970570        57.517481          38.840060     42.000000
# 17999   48.894038        57.521673          38.680952     42.000000
# 18000   48.857226        57.426644          41.300638     42.000000
#
#        Voltage_Difference  Battery_Impedance      Speed  Regen_Triggered  \
# 1               11.175623          84.628469   4.783331            False
# 2               12.444158          84.787273  45.133331            False
# 3               13.329309          84.988065  47.133308            False
# 4                9.244121          85.226445  42.681162            False
# 5               12.051001          84.265367  38.736622            False
# ...                   ...                ...        ...              ...
# 17996           14.191392          86.650225  48.200450            False
# 17997           10.760281          86.089176  29.208722             True
# 17998           10.166872          86.559515  38.249701            False
# 17999           12.064946          86.438554  38.713103            False
# 18000           10.375247          86.329432  46.995598            False
#
#        Regen_Current        SOC  Energy_Consumed_Wh        Ride_ID  \
# 1           0.000000  94.988220            0.341749   2025-01-01_8
# 2           0.000000  94.953326            1.012133   2025-01-01_8
# 3           0.000000  94.917802            1.030212   2025-01-01_8
# 4           0.000000  94.883103            1.006053   2025-01-01_8
# 5           0.000000  94.847689            1.027750   2025-01-01_8
# ...              ...        ...                 ...            ...
# 17996       0.000000  50.615821            3.556871  2025-01-25_18
# 17997     -11.527581  50.505987            3.181712  2025-01-25_18
# 17998       0.000000  50.398829            3.102753  2025-01-25_18
# 17999       0.000000  50.292114            3.090268  2025-01-25_18
# 18000       0.000000  50.178373            3.294107  2025-01-25_18
#
#        Distance_km
# 1         0.006644
# 2         0.062685
# 3         0.065463
# 4         0.059279
# 5         0.053801
# ...            ...
# 17996     0.066945
# 17997     0.040568
# 17998     0.053125
# 17999     0.053768
# 18000     0.065272
#
# [18000 rows x 18 columns]

# %%
calculated_features= df[["Motor_Temp","Battery_Temp","SOC"]]
calculated_features
# Out:
#        Motor_Temp  Battery_Temp        SOC
# 1       28.060000     28.042000  94.988220
# 2       28.236419     28.165914  94.953326
# 3       28.410684     28.289545  94.917802
# 4       28.575685     28.407880  94.883103
# 5       28.739190     28.526264  94.847689
# ...           ...           ...        ...
# 17996   49.111148     42.000000  50.615821
# 17997   49.047126     42.000000  50.505987
# 17998   48.970570     42.000000  50.398829
# 17999   48.894038     42.000000  50.292114
# 18000   48.857226     42.000000  50.178373
#
# [18000 rows x 3 columns]

# %% [markdown]
# ## *Visualising motor current pattern*

# %%
sns.histplot(df['Motor_Current'], bins=20, kde=True)
plt.show()

# %% [markdown]
# # ***Calculating motor-temperature***
# ## ***Physical Principles***
# #### *Motor temperature increases with current draw and time, and cools towards ambient temperature when current is low.*
# #### **1)** *Joule heating: Power loss is proportional to 'I*I*R', so heat generated increases with the square of current.*
# #### **2)** *Cooling: Follows Newton’s Law of Cooling — temperature tends to return to ambient over time.*

# %%
## motor temp calculation 
import numpy as np

# Parameters
ambient_temp = 28  # degrees Celsius
k_heat = 0.00012   # heating constant (tune as needed)
k_cool = 0.001     # cooling constant (tune as needed)
delta_t = 5        # time step in seconds

# Initialize
motor_temp = [ambient_temp]

for i in range(1, len(calculated_features)):
    I = df.loc[i, 'Motor_Current']
    T_prev = motor_temp[-1]
    # Heat gain from current
    delta_T_gain = k_heat * (I ** 2) * delta_t
    # Cooling towards ambient
    delta_T_cool = -k_cool * (T_prev - ambient_temp) * delta_t
    # Update temperature
    T_new = T_prev + delta_T_gain + delta_T_cool
    # Optional: clip to realistic range
    T_new = np.clip(T_new, ambient_temp, 120)  # 120°C as a safety upper bound
    motor_temp.append(T_new)

calculated_features['Motor_Temp'] = motor_temp
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21284\1551920392.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calculated_features['Motor_Temp'] = motor_temp

# %%
sns.histplot(calculated_features['Motor_Temp'],bins=20,kde=True)
# Out:
# <Axes: xlabel='Motor_Temp', ylabel='Count'>

# %% [markdown]
# ### ***It is normal to have right skewed Feature for "Motor temperature" because the temperature will be within the designed operating temperature of the motor and at higher speed and load the temperature increases***

# %% [markdown]
# # ***Calculating battery-temperature***
# ## ***Physical Principles***
# #### *Battery temperature rises due to internal heating from current flow (Joule heating) and returns toward ambient temperature over time via cooling.*
# #### *1) Joule Heating: The primary source of battery heating is I²R loss, where heat generated is proportional to the square of the discharge current (I) and the battery’s internal resistance (R).*
# #### *2) Cooling: The battery cools down towards the ambient temperature, following Newton’s Law of Cooling.*

# %%
## Visualising Discharge_curent
sns.histplot(df["Discharge_Current"],bins=120,kde=True)
# Out:
# <Axes: xlabel='Discharge_Current', ylabel='Count'>

# %%
df["Discharge_Current"].value_counts()
# Out:
# Discharge_Current
# 47.250000    2903
# 4.200000       33
# 11.124515       1
# 11.405321       1
# 12.531656       1
#              ...
# 42.229572       1
# 44.006638       1
# 43.787778       1
# 44.975086       1
# 11.891225       1
# Name: count, Length: 15066, dtype: int64

# %%
plt.boxplot(df['Discharge_Current'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1787c943680>,
#   <matplotlib.lines.Line2D at 0x1787db72480>],
#  'caps': [<matplotlib.lines.Line2D at 0x1787a679ca0>,
#   <matplotlib.lines.Line2D at 0x1787a64bef0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1787c940e30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1787dc093a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1787dbcb950>],
#  'means': []}

# %% [markdown]
# ## *Handling Outliers for Discharge current Feature*

# %%
q1=df['Discharge_Current'].quantile(0.25).round(2)
q3=df['Discharge_Current'].quantile(0.75).round(2)
IQR= q3-q1
lower_fence = (q1 - 1.5* IQR).round(2)
upper_fence = (q3 + 1.5* IQR).round(2)

# %%
print(f"Outliers_count_Discharge_Current: {float(df['Discharge_Current'][ (df['Discharge_Current'] > upper_fence)].value_counts().sum())}")
# Out:
# Outliers_count_Discharge_Current: 0.0

# %% [markdown]
# ## *Since all the outliers are higher than the upper bound value ,it can indicate the necessity of Sudden Throttle or increase of inclined angle.Since the outlier count is only 34(0.18%) so it is left for analysis purpose to determine the reason for spike*

# %%
import numpy as np

AMBIENT_TEMP = 28  # degrees Celsius
THERMAL_THRESHOLD=42
# Use a rolling mean of Discharge_Current to simulate accumulated heating
calculated_features['Battery_Temp'] = AMBIENT_TEMP + 0.15 * df['Discharge_Current'].rolling(10).mean().fillna(0)
calculated_features['Battery_Temp'] += np.random.normal(0, 0.3, len(df))  
calculated_features['Battery_Temp'] = calculated_features['Battery_Temp'].clip(AMBIENT_TEMP, THERMAL_THRESHOLD)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21284\3564107080.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calculated_features['Battery_Temp'] = AMBIENT_TEMP + 0.15 * df['Discharge_Current'].rolling(10).mean().fillna(0)
# C:\Users\hp\AppData\Local\Temp\ipykernel_21284\3564107080.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calculated_features['Battery_Temp'] += np.random.normal(0, 0.3, len(df))
# C:\Users\hp\AppData\Local\Temp\ipykernel_21284\3564107080.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calculated_features['Battery_Temp'] = calculated_features['Battery_Temp'].clip(AMBIENT_TEMP, THERMAL_THRESHOLD)

# %%
sns.histplot(calculated_features['Battery_Temp'],kde=True)
# Out:
# <Axes: xlabel='Battery_Temp', ylabel='Count'>

# %% [markdown]
# # *helper function to derive columns*

# %%
def outliers_viz(table,col):
    q1= table[col].quantile(0.25)
    q3= table[col].quantile(0.75)
    iqr= q3-q1
    lower_bound=q1-1.5*iqr.round(2)
    upper_bound=q3+1.5*iqr.round(2)
    table[col+ "_outliers"]= table[col][(table[col]<= lower_bound)| (table[col] >= upper_bound)]
    outliers_count = table[col + "_outliers"].count()
    sns.histplot(x=table[col],kde=True,element='bars')
    print(f"outliers_count_{col}: {outliers_count}\npercentage of outliers_count_{col}: {((outliers_count/len(table[col]))*100).round(3)}\nSkew_{col}: {table[col].skew().round(2)}")
    print(f"lower_bound: {lower_bound.round(2)},Upper_bound: {upper_bound.round(2)}")

# %%
outliers_viz(calculated_features,"Battery_Temp")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21284\2590340462.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table[col+ "_outliers"]= table[col][(table[col]<= lower_bound)| (table[col] >= upper_bound)]
# outliers_count_Battery_Temp: 0
# percentage of outliers_count_Battery_Temp: 0.0
# Skew_Battery_Temp: -0.14
# lower_bound: 27.27,Upper_bound: 38.34

# %% [markdown]
# # ***Calculating State of Charge (SOC)***
# ## *Physical Principles*
# #### *State of Charge (SOC) is the percentage of remaining energy in a battery compared to its fully charged capacity. It is a key indicator of battery health and performance.*
# #### *Before deriving lets check the dependant columns(Discharge_Current,Battery_Voltage) of the SOC*

# %%
outliers_viz(df,"Discharge_Current")
# Out:
# outliers_count_Discharge_Current: 0
# percentage of outliers_count_Discharge_Current: 0.0
# Skew_Discharge_Current: -0.11
# lower_bound: -5.38,Upper_bound: 69.42

# %%
outliers_viz(df,"Battery_Voltage")
# Out:
# outliers_count_Battery_Voltage: 0
# percentage of outliers_count_Battery_Voltage: 0.0
# Skew_Battery_Voltage: 0.19
# lower_bound: 56.56,Upper_bound: 58.92

# %%
calculated_features['Battery_Voltage_clipped']=df["Battery_Voltage"].clip( 57.11,58.83)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21284\1216390332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calculated_features['Battery_Voltage_clipped']=df["Battery_Voltage"].clip( 57.11,58.83)

# %%
outliers_viz(calculated_features,"Battery_Voltage_clipped")
## can be used if in case needed
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21284\2590340462.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table[col+ "_outliers"]= table[col][(table[col]<= lower_bound)| (table[col] >= upper_bound)]
# outliers_count_Battery_Voltage_clipped: 0
# percentage of outliers_count_Battery_Voltage_clipped: 0.0
# Skew_Battery_Voltage_clipped: 0.19
# lower_bound: 56.56,Upper_bound: 58.92

# %%
soc_derived=pd.DataFrame()

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 1 to 18000
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Timestamp           18000 non-null  datetime64[ns]
#  1   Ride_Mode           18000 non-null  object
#  2   Front_PSI           18000 non-null  float64
#  3   Rear_PSI            18000 non-null  float64
#  4   Motor_Current       18000 non-null  float64
#  5   Motor_Temp          18000 non-null  float64
#  6   Battery_Voltage     18000 non-null  float64
#  7   Discharge_Current   18000 non-null  float64
#  8   Battery_Temp        18000 non-null  float64
#  9   Voltage_Difference  18000 non-null  float64
#  10  Battery_Impedance   18000 non-null  float64
#  11  Speed               18000 non-null  float64
#  12  Regen_Triggered     18000 non-null  bool
#  13  Regen_Current       18000 non-null  float64
#  14  SOC                 18000 non-null  float64
#  15  Energy_Consumed_Wh  18000 non-null  float64
#  16  Ride_ID             18000 non-null  object
#  17  Distance_km         18000 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(14), object(2)
# memory usage: 2.4+ MB

# %%
df
# Out:
#                 Timestamp  Ride_Mode  Front_PSI   Rear_PSI  Motor_Current  \
# 1     2025-01-01 08:00:00  Smart Eco  22.072488  36.041235       4.000000
# 2     2025-01-01 08:00:05  Smart Eco  22.103992  34.300000      11.881297
# 3     2025-01-01 08:00:10  Smart Eco  22.061601  35.998044      12.090489
# 4     2025-01-01 08:00:15  Smart Eco  22.138960  35.911912      11.821425
# 5     2025-01-01 08:00:20  Smart Eco  22.082344  35.825733      12.051667
# ...                   ...        ...        ...        ...            ...
# 17996 2025-01-25 18:29:35  Smart Eco  19.940938  32.526712      42.527883
# 17997 2025-01-25 18:29:40  Smart Eco  20.047073  32.555176      37.954161
# 17998 2025-01-25 18:29:45  Smart Eco  19.947056  32.632559      36.990533
# 17999 2025-01-25 18:29:50  Smart Eco  19.982741  32.526898      36.839002
# 18000 2025-01-25 18:29:55  Smart Eco  19.972233  32.387305      39.333941
#
#        Motor_Temp  Battery_Voltage  Discharge_Current  Battery_Temp  \
# 1       28.060000        58.585477           4.200000     28.042000
# 2       28.236419        58.413992          12.475362     28.165914
# 3       28.410684        58.428662          12.695014     28.289545
# 4       28.575685        58.357180          12.412497     28.407880
# 5       28.739190        58.476819          12.654250     28.526264
# ...           ...              ...                ...           ...
# 17996   49.111148        57.350538          44.654277     42.000000
# 17997   49.047126        57.483695          39.851869     42.000000
# 17998   48.970570        57.517481          38.840060     42.000000
# 17999   48.894038        57.521673          38.680952     42.000000
# 18000   48.857226        57.426644          41.300638     42.000000
#
#        Voltage_Difference  Battery_Impedance      Speed  Regen_Triggered  \
# 1               11.175623          84.628469   4.783331            False
# 2               12.444158          84.787273  45.133331            False
# 3               13.329309          84.988065  47.133308            False
# 4                9.244121          85.226445  42.681162            False
# 5               12.051001          84.265367  38.736622            False
# ...                   ...                ...        ...              ...
# 17996           14.191392          86.650225  48.200450            False
# 17997           10.760281          86.089176  29.208722             True
# 17998           10.166872          86.559515  38.249701            False
# 17999           12.064946          86.438554  38.713103            False
# 18000           10.375247          86.329432  46.995598            False
#
#        Regen_Current        SOC  Energy_Consumed_Wh        Ride_ID  \
# 1           0.000000  94.988220            0.341749   2025-01-01_8
# 2           0.000000  94.953326            1.012133   2025-01-01_8
# 3           0.000000  94.917802            1.030212   2025-01-01_8
# 4           0.000000  94.883103            1.006053   2025-01-01_8
# 5           0.000000  94.847689            1.027750   2025-01-01_8
# ...              ...        ...                 ...            ...
# 17996       0.000000  50.615821            3.556871  2025-01-25_18
# 17997     -11.527581  50.505987            3.181712  2025-01-25_18
# 17998       0.000000  50.398829            3.102753  2025-01-25_18
# 17999       0.000000  50.292114            3.090268  2025-01-25_18
# 18000       0.000000  50.178373            3.294107  2025-01-25_18
#
#        Distance_km  Discharge_Current_outliers  Battery_Voltage_outliers
# 1         0.006644                         NaN                       NaN
# 2         0.062685                         NaN                       NaN
# 3         0.065463                         NaN                       NaN
# 4         0.059279                         NaN                       NaN
# 5         0.053801                         NaN                       NaN
# ...            ...                         ...                       ...
# 17996     0.066945                         NaN                       NaN
# 17997     0.040568                         NaN                       NaN
# 17998     0.053125                         NaN                       NaN
# 17999     0.053768                         NaN                       NaN
# 18000     0.065272                         NaN                       NaN
#
# [18000 rows x 20 columns]

# %%
# %who DataFrame
# Out:
# acc_cal	 calculated_features	 cleaned_df	 df	 null_cols	 outlier_columns	 soc_dep	 soc_derived

# %%
soc_derived=pd.DataFrame(columns=['Discharge_Current','Battery_Voltage'],index=[i for i in range(1,len(soc_derived))] )

# %%
# %who DataFrame
# Out:
# acc_cal	 calculated_features	 cleaned_df	 df	 null_cols	 outlier_columns	 soc_dep	 soc_derived

# %%
soc_derived
# Out:
# Empty DataFrame
# Columns: [Discharge_Current, Battery_Voltage]
# Index: []

# %%
soc_derived[["Discharge_Current",'Battery_Voltage']]=df[['Discharge_Current',"Battery_Voltage"]]

# %%
soc_derived
# Out:
#        Discharge_Current  Battery_Voltage
# 1               4.200000        58.585477
# 2              12.475362        58.413992
# 3              12.695014        58.428662
# 4              12.412497        58.357180
# 5              12.654250        58.476819
# ...                  ...              ...
# 17996          44.654277        57.350538
# 17997          39.851869        57.483695
# 17998          38.840060        57.517481
# 17999          38.680952        57.521673
# 18000          41.300638        57.426644
#
# [18000 rows x 2 columns]

# %%
outliers_viz(soc_derived,"Discharge_Current")
# Out:
# outliers_count_Discharge_Current: 0
# percentage of outliers_count_Discharge_Current: 0.0
# Skew_Discharge_Current: -0.11
# lower_bound: -5.38,Upper_bound: 69.42

# %%
outliers_viz(soc_derived,"Battery_Voltage")
# Out:
# outliers_count_Battery_Voltage: 0
# percentage of outliers_count_Battery_Voltage: 0.0
# Skew_Battery_Voltage: 0.19
# lower_bound: 56.56,Upper_bound: 58.92

# %% [markdown]
# ## ***SOC Calculation Using Discharge Current and Battery Voltage***

# %%
# Constants
INITIAL_SOC = 95  # percent
BATTERY_CAPACITY_WH = 2900  # watt-hours (2.9 kWh)
# Time delta: assume 5 seconds per sample (adjust if your data is different)
TIME_DELTA_HOURS = 5 / 3600  # 5 seconds in hours

# Clip or filter out negative discharge current (regen)
soc_derived['Discharge_Current_Used'] = soc_derived['Discharge_Current'].clip(lower=0)
outliers_viz(soc_derived,"Discharge_Current_Used")
# Out:
# outliers_count_Discharge_Current_Used: 0
# percentage of outliers_count_Discharge_Current_Used: 0.0
# Skew_Discharge_Current_Used: -0.11
# lower_bound: -5.38,Upper_bound: 69.42

# %%
soc_derived['Energy_Removed_Wh'] = (
    soc_derived['Discharge_Current_Used'] * soc_derived['Battery_Voltage'] * TIME_DELTA_HOURS )
outliers_viz(soc_derived,"Energy_Removed_Wh")
# Out:
# outliers_count_Energy_Removed_Wh: 0
# percentage of outliers_count_Energy_Removed_Wh: 0.0
# Skew_Energy_Removed_Wh: -0.12
# lower_bound: -0.38,Upper_bound: 5.5

# %%
soc_derived['Cumulative_Energy_Removed_Wh'] = soc_derived['Energy_Removed_Wh'].cumsum()
outliers_viz(soc_derived,"Cumulative_Energy_Removed_Wh")
# Out:
# outliers_count_Cumulative_Energy_Removed_Wh: 0
# percentage of outliers_count_Cumulative_Energy_Removed_Wh: 0.0
# Skew_Cumulative_Energy_Removed_Wh: 0.28
# lower_bound: -28280.91,Upper_bound: 66441.05

# %%
soc_derived
# Out:
#        Discharge_Current  Battery_Voltage  Discharge_Current_outliers  \
# 1               4.200000        58.585477                         NaN
# 2              12.475362        58.413992                         NaN
# 3              12.695014        58.428662                         NaN
# 4              12.412497        58.357180                         NaN
# 5              12.654250        58.476819                         NaN
# ...                  ...              ...                         ...
# 17996          44.654277        57.350538                         NaN
# 17997          39.851869        57.483695                         NaN
# 17998          38.840060        57.517481                         NaN
# 17999          38.680952        57.521673                         NaN
# 18000          41.300638        57.426644                         NaN
#
#        Battery_Voltage_outliers  Discharge_Current_Used  \
# 1                           NaN                4.200000
# 2                           NaN               12.475362
# 3                           NaN               12.695014
# 4                           NaN               12.412497
# 5                           NaN               12.654250
# ...                         ...                     ...
# 17996                       NaN               44.654277
# 17997                       NaN               39.851869
# 17998                       NaN               38.840060
# 17999                       NaN               38.680952
# 18000                       NaN               41.300638
#
#        Discharge_Current_Used_outliers  Energy_Removed_Wh  \
# 1                                  NaN           0.341749
# 2                                  NaN           1.012133
# 3                                  NaN           1.030212
# 4                                  NaN           1.006053
# 5                                  NaN           1.027750
# ...                                ...                ...
# 17996                              NaN           3.556871
# 17997                              NaN           3.181712
# 17998                              NaN           3.102753
# 17999                              NaN           3.090268
# 18000                              NaN           3.294107
#
#        Energy_Removed_Wh_outliers  Cumulative_Energy_Removed_Wh  \
# 1                             NaN                      0.341749
# 2                             NaN                      1.353882
# 3                             NaN                      2.384094
# 4                             NaN                      3.390147
# 5                             NaN                      4.417897
# ...                           ...                           ...
# 17996                         NaN                  45877.104802
# 17997                         NaN                  45880.286514
# 17998                         NaN                  45883.389267
# 17999                         NaN                  45886.479535
# 18000                         NaN                  45889.773643
#
#        Cumulative_Energy_Removed_Wh_outliers
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# ...                                      ...
# 17996                                    NaN
# 17997                                    NaN
# 17998                                    NaN
# 17999                                    NaN
# 18000                                    NaN
#
# [18000 rows x 10 columns]

# %%
# Identify ride start points (e.g., every 1800 samples or by timestamp gap)
ride_length = 1800  # number of samples per ride
soc_derived['Ride_ID'] = (np.arange(len(soc_derived)) // ride_length).astype(int)

# Calculate SOC per ride
soc_derived['SOC'] = np.nan
for ride_id in soc_derived['Ride_ID'].unique():
    idx = soc_derived['Ride_ID'] == ride_id
    cumulative_energy = soc_derived.loc[idx, 'Energy_Removed_Wh'].cumsum()
    soc = INITIAL_SOC - (cumulative_energy / BATTERY_CAPACITY_WH * 100)
    soc += np.random.normal(0, 0.2, soc.shape[0])
    soc = soc.clip(20, 95)
    soc_derived.loc[idx, 'SOC'] = soc.values

# %%
# BATTERY_CAPACITY_WH = 2900 
soc_derived['SOC'] = INITIAL_SOC - (soc_derived['Cumulative_Energy_Removed_Wh'] / BATTERY_CAPACITY_WH * 100)
# Add a small noise for realism
soc_derived['SOC'] += np.random.normal(0, 0.2, len(soc_derived))
# Clip to realistic SOC range (e.g., 20 to 95)
soc_derived['SOC'] = soc_derived['SOC'].clip(20, 95)
outliers_viz(soc_derived,"SOC")
# Out:
# outliers_count_SOC: 18000
# percentage of outliers_count_SOC: 100.0
# Skew_SOC: 3.86
# lower_bound: 20.0,Upper_bound: 20.0

# %%
outliers_viz(soc_derived,"SOC")
# Out:
# outliers_count_SOC: 18000
# percentage of outliers_count_SOC: 100.0
# Skew_SOC: 3.86
# lower_bound: 20.0,Upper_bound: 20.0

# %%
df["SOC"] = soc_derived["SOC"]

# %%
outliers_viz(df,"SOC")
# Out:
# outliers_count_SOC: 18000
# percentage of outliers_count_SOC: 100.0
# Skew_SOC: 3.86
# lower_bound: 20.0,Upper_bound: 20.0

# %% [markdown]
# ## ***Acceleration  Calculation***

# %%
outliers_viz(df,"Speed")
# Out:
# outliers_count_Speed: 896
# percentage of outliers_count_Speed: 4.978
# Skew_Speed: 0.71
# lower_bound: 23.7,Upper_bound: 73.78

# %%
acc_cal=pd.DataFrame(columns=["Speed","Acceleration"],index=[i for i in range(1,len(df)+1)] )

# %%
# --- Speed Profile with Realistic Start ---

# Parameters
segment_length = int((30 * 60) / 5)  # 30 minutes, 5s interval = 360 samples per segment
target_speed_smart = 45  # km/h for Smart Eco
target_speed_zip = 65    # km/h for Zip
accel_time = 60          # seconds to reach target speed (adjust as needed)
accel_steps = int(accel_time / 5)  # number of steps to reach target

speeds = []
i = 0
while i < len(df):
    # Determine ride mode for this segment
    ride_mode = df['Ride_Mode'].iloc[i]
    if ride_mode == 'Smart Eco':
        target_speed = np.random.normal(target_speed_smart, 2)
    else:
        target_speed = np.random.normal(target_speed_zip, 3)
    # Optionally, adjust for tyre pressure and discharge current
    avg_psi = (df['Front_PSI'].iloc[i:i+segment_length].mean() + df['Rear_PSI'].iloc[i:i+segment_length].mean()) / 2
    psi_factor = 1.0 if avg_psi > 30 else 0.95  # Lower pressure reduces max speed
    discharge_factor = 1.0 if df['Discharge_Current'].iloc[i:i+segment_length].mean() < 30 else 0.97

    target_speed = target_speed * psi_factor * discharge_factor

    # Ramp up from 0 to target speed
    ramp = np.linspace(0, target_speed, accel_steps)
    # Stay near target speed with some noise
    cruise = np.random.normal(target_speed, 2, segment_length - accel_steps)
    segment_speed = np.concatenate([ramp, cruise])
    segment_speed = np.clip(segment_speed, 0, 90)  # Physical max

    # Add to list
    speeds.extend(segment_speed[:segment_length])
    i += segment_length

# If speeds is longer than df, trim; if shorter, pad
speeds = speeds[:len(df)]
if len(speeds) < len(df):
    speeds += [speeds[-1]] * (len(df) - len(speeds))

acc_cal['Speed'] = speeds

# %%
outliers_viz(acc_cal,"Speed")
# Out:
# outliers_count_Speed: 184
# percentage of outliers_count_Speed: 1.022
# Skew_Speed: -0.22
# lower_bound: 14.54,Upper_bound: 84.5

# %%
df["Speed"]=acc_cal["Speed"]

# %%
outliers_viz(df,"Speed")
# Out:
# outliers_count_Speed: 184
# percentage of outliers_count_Speed: 1.022
# Skew_Speed: -0.22
# lower_bound: 14.54,Upper_bound: 84.5

# %%
# Convert speed from km/h to m/s
acc_cal['Speed_mps'] = acc_cal['Speed'] * 0.27778

# Calculate acceleration (m/s²)
# Δt = 5 seconds (sampling interval)
acc_cal['Acceleration'] = acc_cal['Speed_mps'].diff() / 5

# Clip to physical limits (e.g., -3 to +3 m/s² for a scooter)
acc_cal['Acceleration'] = acc_cal['Acceleration'].clip(-3, 3)

# %%
outliers_viz(acc_cal,"Acceleration")
# Out:
# outliers_count_Acceleration: 132
# percentage of outliers_count_Acceleration: 0.733
# Skew_Acceleration: -5.24
# lower_bound: -0.43,Upper_bound: 0.45

# %%
df["Acceleration"]= acc_cal["Acceleration"]

# %%
df
# Out:
#                 Timestamp  Ride_Mode  Front_PSI   Rear_PSI  Motor_Current  \
# 1     2025-01-01 08:00:00  Smart Eco  22.072488  36.041235       4.000000
# 2     2025-01-01 08:00:05  Smart Eco  22.103992  34.300000      11.881297
# 3     2025-01-01 08:00:10  Smart Eco  22.061601  35.998044      12.090489
# 4     2025-01-01 08:00:15  Smart Eco  22.138960  35.911912      11.821425
# 5     2025-01-01 08:00:20  Smart Eco  22.082344  35.825733      12.051667
# ...                   ...        ...        ...        ...            ...
# 17996 2025-01-25 18:29:35  Smart Eco  19.940938  32.526712      42.527883
# 17997 2025-01-25 18:29:40  Smart Eco  20.047073  32.555176      37.954161
# 17998 2025-01-25 18:29:45  Smart Eco  19.947056  32.632559      36.990533
# 17999 2025-01-25 18:29:50  Smart Eco  19.982741  32.526898      36.839002
# 18000 2025-01-25 18:29:55  Smart Eco  19.972233  32.387305      39.333941
#
#        Motor_Temp  Battery_Voltage  Discharge_Current  Battery_Temp  \
# 1       28.060000        58.585477           4.200000     28.042000
# 2       28.236419        58.413992          12.475362     28.165914
# 3       28.410684        58.428662          12.695014     28.289545
# 4       28.575685        58.357180          12.412497     28.407880
# 5       28.739190        58.476819          12.654250     28.526264
# ...           ...              ...                ...           ...
# 17996   49.111148        57.350538          44.654277     42.000000
# 17997   49.047126        57.483695          39.851869     42.000000
# 17998   48.970570        57.517481          38.840060     42.000000
# 17999   48.894038        57.521673          38.680952     42.000000
# 18000   48.857226        57.426644          41.300638     42.000000
#
#        Voltage_Difference  ...  Regen_Current        SOC  Energy_Consumed_Wh  \
# 1               11.175623  ...       0.000000  95.000000            0.341749
# 2               12.444158  ...       0.000000  94.949045            1.012133
# 3               13.329309  ...       0.000000  94.696898            1.030212
# 4                9.244121  ...       0.000000  94.858833            1.006053
# 5               12.051001  ...       0.000000  94.951404            1.027750
# ...                   ...  ...            ...        ...                 ...
# 17996           14.191392  ...       0.000000  20.000000            3.556871
# 17997           10.760281  ...     -11.527581  20.000000            3.181712
# 17998           10.166872  ...       0.000000  20.000000            3.102753
# 17999           12.064946  ...       0.000000  20.000000            3.090268
# 18000           10.375247  ...       0.000000  20.000000            3.294107
#
#              Ride_ID  Distance_km  Discharge_Current_outliers  \
# 1       2025-01-01_8     0.006644                         NaN
# 2       2025-01-01_8     0.062685                         NaN
# 3       2025-01-01_8     0.065463                         NaN
# 4       2025-01-01_8     0.059279                         NaN
# 5       2025-01-01_8     0.053801                         NaN
# ...              ...          ...                         ...
# 17996  2025-01-25_18     0.066945                         NaN
# 17997  2025-01-25_18     0.040568                         NaN
# 17998  2025-01-25_18     0.053125                         NaN
# 17999  2025-01-25_18     0.053768                         NaN
# 18000  2025-01-25_18     0.065272                         NaN
#
#       Battery_Voltage_outliers  SOC_outliers  Speed_outliers  Acceleration
# 1                          NaN     95.000000          0.0000           NaN
# 2                          NaN     94.949045          4.0285      0.223807
# 3                          NaN     94.696898          8.0570      0.223807
# 4                          NaN     94.858833         12.0855      0.223807
# 5                          NaN     94.951404             NaN      0.223807
# ...                        ...           ...             ...           ...
# 17996                      NaN     20.000000             NaN     -0.398247
# 17997                      NaN     20.000000             NaN      0.250248
# 17998                      NaN     20.000000             NaN      0.084549
# 17999                      NaN     20.000000             NaN     -0.198221
# 18000                      NaN     20.000000             NaN     -0.108998
#
# [18000 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Timestamp', 'Ride_Mode', 'Front_PSI', 'Rear_PSI', 'Motor_Current',
#        'Motor_Temp', 'Battery_Voltage', 'Discharge_Current', 'Battery_Temp',
#        'Voltage_Difference', 'Battery_Impedance', 'Speed', 'Regen_Triggered',
#        'Regen_Current', 'SOC', 'Energy_Consumed_Wh', 'Ride_ID', 'Distance_km',
#        'Discharge_Current_outliers', 'Battery_Voltage_outliers',
#        'SOC_outliers', 'Speed_outliers', 'Acceleration'],
#       dtype='object')

# %%
df.drop(columns=['Discharge_Current_outliers',
       'Battery_Voltage_outliers', 'SOC_outliers', 'Speed_outliers'],inplace=True)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Ride_Mode', 'Front_PSI', 'Rear_PSI', 'Motor_Current',
#        'Motor_Temp', 'Battery_Voltage', 'Discharge_Current', 'Battery_Temp',
#        'Voltage_Difference', 'Battery_Impedance', 'Speed', 'Regen_Triggered',
#        'Regen_Current', 'SOC', 'Energy_Consumed_Wh', 'Ride_ID', 'Distance_km',
#        'Acceleration'],
#       dtype='object')

# %%
df.shape
# Out:
# (18000, 19)

# %%
df.to_csv("AtherRizta_Cleaned_datsetv2.csv",index = False)

# %%
import pandas as pd
import seaborn as sns

# %%
cleaned_df= pd.read_csv("AtherRizta_Cleaned_datsetv2.csv",index_col = False)

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Timestamp           18000 non-null  object
#  1   Ride_Mode           18000 non-null  object
#  2   Front_PSI           18000 non-null  float64
#  3   Rear_PSI            18000 non-null  float64
#  4   Motor_Current       18000 non-null  float64
#  5   Motor_Temp          18000 non-null  float64
#  6   Battery_Voltage     18000 non-null  float64
#  7   Discharge_Current   18000 non-null  float64
#  8   Battery_Temp        18000 non-null  float64
#  9   Voltage_Difference  18000 non-null  float64
#  10  Battery_Impedance   18000 non-null  float64
#  11  Speed               18000 non-null  float64
#  12  Regen_Triggered     18000 non-null  bool
#  13  Regen_Current       18000 non-null  float64
#  14  SOC                 18000 non-null  float64
#  15  Energy_Consumed_Wh  18000 non-null  float64
#  16  Ride_ID             18000 non-null  object
#  17  Distance_km         18000 non-null  float64
#  18  Acceleration        17999 non-null  float64
# dtypes: bool(1), float64(15), object(3)
# memory usage: 2.5+ MB

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Timestamp           18000 non-null  object
#  1   Ride_Mode           18000 non-null  object
#  2   Front_PSI           18000 non-null  float64
#  3   Rear_PSI            18000 non-null  float64
#  4   Motor_Current       18000 non-null  float64
#  5   Motor_Temp          18000 non-null  float64
#  6   Battery_Voltage     18000 non-null  float64
#  7   Discharge_Current   18000 non-null  float64
#  8   Battery_Temp        18000 non-null  float64
#  9   Voltage_Difference  18000 non-null  float64
#  10  Battery_Impedance   18000 non-null  float64
#  11  Speed               18000 non-null  float64
#  12  Regen_Triggered     18000 non-null  bool
#  13  Regen_Current       18000 non-null  float64
#  14  SOC                 18000 non-null  float64
#  15  Energy_Consumed_Wh  18000 non-null  float64
#  16  Ride_ID             18000 non-null  object
#  17  Distance_km         18000 non-null  float64
#  18  Acceleration        17999 non-null  float64
# dtypes: bool(1), float64(15), object(3)
# memory usage: 2.5+ MB

# %%
cleaned_df.describe()
# Out:
#          Unnamed: 0     Front_PSI      Rear_PSI  Motor_Current    Motor_Temp  \
# count  18000.000000  18000.000000  18000.000000   18000.000000  18000.000000
# mean    9000.500000     21.038979     34.271230      30.334528     41.879422
# std     5196.296758      0.636482      1.036820      10.469170      5.425367
# min        1.000000     19.785705     32.290501       4.000000     28.060000
# 25%     4500.750000     20.493281     33.374800      21.587489     37.558077
# 50%     9000.500000     21.032304     34.284289      30.572064     42.189955
# 75%    13500.250000     21.586548     35.157517      39.397192     46.592611
# max    18000.000000     22.237094     36.252165      45.000000     50.474559
#
#        Battery_Voltage  Discharge_Current  Battery_Temp  Voltage_Difference  \
# count     18000.000000       18000.000000  18000.000000        18000.000000
# mean         57.750592          31.851255     39.455966           12.010838
# std           0.364207          10.992629      3.485287            1.997210
# min          56.913806           4.200000     28.042000            5.000000
# 25%          57.444426          22.666864     37.322460           10.682975
# 50%          57.729348          32.100667     41.781280           12.000000
# 75%          58.037739          41.367052     42.000000           13.365163
# max          58.800000          47.250000     42.000000           20.000000
#
#        Battery_Impedance         Speed  Regen_Current           SOC  \
# count       18000.000000  18000.000000   18000.000000  18000.000000
# mean           85.504369     48.048706      -4.275413     23.617319
# std             0.507170     10.397649       6.692359     13.350715
# min            83.855742      0.000000     -15.000000     20.000000
# 25%            85.150408     41.392929     -14.271645     20.000000
# 50%            85.503240     44.358538       0.000000     20.000000
# 75%            85.853473     58.476837       0.000000     20.000000
# max            87.496981     70.262384       0.000000     95.000000
#
#        Energy_Consumed_Wh   Distance_km  Acceleration
# count        18000.000000  18000.000000  17999.000000
# mean             2.549432      0.069361      0.000537
# std              0.867045      0.015655      0.210963
# min              0.341306      0.004178     -3.000000
# 25%              1.826084      0.059005     -0.104602
# 50%              2.574679      0.066035      0.005461
# 75%              3.299894      0.076389      0.119330
# max              3.780685      0.111111      0.621646

# %%
sns.histplot(cleaned_df["Motor_Current"],kde=True,bins='auto')
# Out:
# <Axes: xlabel='Motor_Current', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

def box_plots(table):
    # Loop only over numeric columns
    for col in table.select_dtypes(include='number').columns:
        plt.figure(figsize=(4, 5))
        plt.boxplot(table[col].dropna(), vert=True)
        plt.title(f'Boxplot of {col}')
        plt.ylabel(col)
        plt.grid(True)
        plt.show()

# %%
#cleaned_df.to_csv("AtherRizta_Cleaned_datset.csv",index=False)

# %%
#df=pd.read_csv("AtherRizta_Cleaned_datset.csv")

# %%
df
# Out:
#                 Timestamp  Ride_Mode  Front_PSI   Rear_PSI  Motor_Current  \
# 1     2025-01-01 08:00:00  Smart Eco  22.072488  36.041235       4.000000
# 2     2025-01-01 08:00:05  Smart Eco  22.103992  34.300000      11.881297
# 3     2025-01-01 08:00:10  Smart Eco  22.061601  35.998044      12.090489
# 4     2025-01-01 08:00:15  Smart Eco  22.138960  35.911912      11.821425
# 5     2025-01-01 08:00:20  Smart Eco  22.082344  35.825733      12.051667
# ...                   ...        ...        ...        ...            ...
# 17996 2025-01-25 18:29:35  Smart Eco  19.940938  32.526712      42.527883
# 17997 2025-01-25 18:29:40  Smart Eco  20.047073  32.555176      37.954161
# 17998 2025-01-25 18:29:45  Smart Eco  19.947056  32.632559      36.990533
# 17999 2025-01-25 18:29:50  Smart Eco  19.982741  32.526898      36.839002
# 18000 2025-01-25 18:29:55  Smart Eco  19.972233  32.387305      39.333941
#
#        Motor_Temp  Battery_Voltage  Discharge_Current  Battery_Temp  \
# 1       28.060000        58.585477           4.200000     28.042000
# 2       28.236419        58.413992          12.475362     28.165914
# 3       28.410684        58.428662          12.695014     28.289545
# 4       28.575685        58.357180          12.412497     28.407880
# 5       28.739190        58.476819          12.654250     28.526264
# ...           ...              ...                ...           ...
# 17996   49.111148        57.350538          44.654277     42.000000
# 17997   49.047126        57.483695          39.851869     42.000000
# 17998   48.970570        57.517481          38.840060     42.000000
# 17999   48.894038        57.521673          38.680952     42.000000
# 18000   48.857226        57.426644          41.300638     42.000000
#
#        Voltage_Difference  Battery_Impedance      Speed  Regen_Triggered  \
# 1               11.175623          84.628469   4.783331            False
# 2               12.444158          84.787273  45.133331            False
# 3               13.329309          84.988065  47.133308            False
# 4                9.244121          85.226445  42.681162            False
# 5               12.051001          84.265367  38.736622            False
# ...                   ...                ...        ...              ...
# 17996           14.191392          86.650225  48.200450            False
# 17997           10.760281          86.089176  29.208722             True
# 17998           10.166872          86.559515  38.249701            False
# 17999           12.064946          86.438554  38.713103            False
# 18000           10.375247          86.329432  46.995598            False
#
#        Regen_Current        SOC  Energy_Consumed_Wh        Ride_ID  \
# 1           0.000000  94.988220            0.341749   2025-01-01_8
# 2           0.000000  94.953326            1.012133   2025-01-01_8
# 3           0.000000  94.917802            1.030212   2025-01-01_8
# 4           0.000000  94.883103            1.006053   2025-01-01_8
# 5           0.000000  94.847689            1.027750   2025-01-01_8
# ...              ...        ...                 ...            ...
# 17996       0.000000  50.615821            3.556871  2025-01-25_18
# 17997     -11.527581  50.505987            3.181712  2025-01-25_18
# 17998       0.000000  50.398829            3.102753  2025-01-25_18
# 17999       0.000000  50.292114            3.090268  2025-01-25_18
# 18000       0.000000  50.178373            3.294107  2025-01-25_18
#
#        Distance_km
# 1         0.006644
# 2         0.062685
# 3         0.065463
# 4         0.059279
# 5         0.053801
# ...            ...
# 17996     0.066945
# 17997     0.040568
# 17998     0.053125
# 17999     0.053768
# 18000     0.065272
#
# [18000 rows x 18 columns]

# %%
df.to_csv("AtherRizta_Cleaned_datsetv3.csv",index = False)

# %%
cleaned_df.groupby('Ride_Mode').agg({"Ride_Mode":"count"})
# Out:
#            Ride_Mode
# Ride_Mode
# Smart Eco      13295
# Zip             4705
